# %%
import aco as aco
import random 
import numpy as np
import threading
import time

import prog_lineraire as pl
import generator_matrix as gm
import dataset
import json
import pandas as pd

# %%
matrice= dataset.import_dataset("dataset/small_dataset_0")
villes = dataset.import_dataset("dataset/small_cities_0")

# %%
pl.get_borne_inf(matrice, villes)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/colin/.local/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/87bf99bb53b0425aa79ed044caaeedad-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/87bf99bb53b0425aa79ed044caaeedad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 80 COLUMNS
# At line 3206 RHS
# At line 3282 BOUNDS
# At line 3908 ENDATA
# Problem MODEL has 75 rows, 625 columns and 1275 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3801.62 - 0.00 seconds
# Cgl0002I 25 variables fixed
# Cgl0004I processed model has 50 rows, 600 columns (600 integer (600 of which binary)) and 1200 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 3801.62
# ...

# %%
parameters = {
    "nbr_ant":50,
    "a":1.75,
    "b":3.00,
    "p":.4,
    "nb_iter_max":1000,
    "time_max":60,
    "nbr_random_search":10,
    "nbr_loops":5,
}

constraint = {
    "start":4,
    "city":18,
    "inferior_dist":1000,
    "superior_dist":2000,
}
res = []

aco.aco_algorithm(matrice,parameters,res,constraint)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\CESI\A3\Bloc Algorithmique avancee\Projet\Git\projet_algo\debug.ipynb Cell 1' in <cell line: 20>()
#      <a href='vscode-notebook-cell:/d%3A/CESI/A3/Bloc%20Algorithmique%20avancee/Projet/Git/projet_algo/debug.ipynb#ch0000000?line=11'>12</a> constraint = {
#      <a href='vscode-notebook-cell:/d%3A/CESI/A3/Bloc%20Algorithmique%20avancee/Projet/Git/projet_algo/debug.ipynb#ch0000000?line=12'>13</a>     "start":4,
#      <a href='vscode-notebook-cell:/d%3A/CESI/A3/Bloc%20Algorithmique%20avancee/Projet/Git/projet_algo/debug.ipynb#ch0000000?line=13'>14</a>     "city":18,
#      <a href='vscode-notebook-cell:/d%3A/CESI/A3/Bloc%20Algorithmique%20avancee/Projet/Git/projet_algo/debug.ipynb#ch0000000?line=14'>15</a>     "inferior_dist":1000,
# ...

# %%
path = [4, 1, 18]
aco.path_distance(path,matrice,constraint)
# Out:
# 297.10635168448096
